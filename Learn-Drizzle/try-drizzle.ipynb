# %% [markdown]
# * https://github.com/trufflesuite/drizzle
# * https://www.trufflesuite.com/drizzle
# * https://www.trufflesuite.com/docs/drizzle/react/react-integration

# %% [markdown]
# * https://www.trufflesuite.com/boxes/drizzle

# %%
npm install -g node-gyp

# %%
mkdir unbox-drizzle && cd unbox-drizzle

# %%
npx truffle unbox drizzle
# Out:
# Starting unbox...
# ...
#
# ⠋ Preparing to download box✔ Preparing to download box
# ⠋ Downloading⠙ Downloading⠹ Downloading⠸ Downloading⠼ Downloading⠴ Downloading⠦ Downloading⠧ Downloading⠇ Downloading⠏ Downloading⠋ Downloading⠙ Downloading⠹ Downloading⠸ Downloading⠼ Downloading⠴ Downloading⠦ Downloading⠧ Downloading⠇ Downloading⠏ Downloading⠋ Downloading⠙ Downloading⠹ Downloading⠸ Downloading⠼ Downloading⠴ Downloading⠦ Downloading⠧ Downloading⠇ Downloading✔ Downloading
# npm WARN deprecated fsevents@1.2.9: fsevents 1 will break on node v14+ and could be using insecure binaries. Upgrade to fsevents 2.
# npm WARN deprecated fsevents@1.2.9: fsevents 1 will break on node v14+ and could be using insecure binaries. Upgrade to fsevents 2.
# npm WARN deprecated mkdirp-promise@5.0.1: This package is broken and no longer maintained. 'mkdirp' itself supports promises now, please switch to that.
# ...

# %%
cd .. && rm -rf unbox-drizzle

# %% [markdown]
# * https://github.com/truffle-box/drizzle-box

# %%
git clone https://github.com/truffle-box/drizzle-box unbox-drizzle
# Out:
# Cloning into 'unbox-drizzle'...
# remote: Enumerating objects: 131, done.
# remote: Counting objects: 100% (131/131), done.
# remote: Compressing objects: 100% (104/104), done.
# remote: Total 636 (delta 72), reused 54 (delta 26), pack-reused 505
# Receiving objects: 100% (636/636), 1.24 MiB | 1.37 MiB/s, done.
# Resolving deltas: 100% (283/283), done.

# %%
cd unbox-drizzle && npm i
# Out:
#               ⸩ ⠏ reify:@openzeppelin/contracts: timing reify:loadBundles0m
# added 1 package, and audited 1 package in 2s
#
# found 0 vulnerabilities

# %%
cd app && mkdir -p tmp && cd tmp && npm init --yes && npm install sha3@^1.2.2
# Out:
# Wrote to /Users/saintway/JHub/demo-ethereum-dapp/Learn-Drizzle/unbox-drizzle/app/tmp/package.json:
#
# {
#   "name": "tmp",
#   "version": "1.0.0",
#   "description": "",
#   "main": "index.js",
#   "scripts": {
#     "test": "echo \"Error: no test specified\" && exit 1"
#   },
#   "keywords": [],
#   "author": "",
#   "license": "ISC"
# }
#
#
#               ⸩ ⠼ reify:sha3: timing reifyNode:node_modules/nan Completed
# added 2 packages, and audited 2 packages in 2s
#
# found 0 vulnerabilities

# %%
mv node_modules .. && cd .. && rm -rf tmp && npm install
# Out:
# npm WARN deprecated fsevents@1.2.9: fsevents 1 will break on node v14+ and could be using insecure binaries. Upgrade to fsevents 2.
# npm WARN deprecated fsevents@1.2.9: fsevents 1 will break on node v14+ and could be using insecure binaries. Upgrade to fsevents 2.
# npm WARN deprecated mkdirp-promise@5.0.1: This package is broken and no longer maintained. 'mkdirp' itself supports promises now, please switch to that.
# npm WARN deprecated flatten@1.0.2: I wrote this module a very long time ago; you should use something else.
# npm WARN deprecated @hapi/bourne@1.3.2: This version has been deprecated and is no longer supported or maintained
# npm WARN deprecated @hapi/topo@3.1.4: This version has been deprecated and is no longer supported or maintained
# npm WARN deprecated urix@0.1.0: Please see https://github.com/lydell/urix#deprecated
# npm WARN deprecated har-validator@5.1.3: this library is no longer supported
# ...

# %%
cd .. && truffle compile --all
# Out:
# Compiling your contracts...
# ...
# > Compiling ./contracts/ComplexStorage.sol
# > Compiling ./contracts/Migrations.sol
# > Compiling ./contracts/SimpleStorage.sol
# > Compiling ./contracts/TutorialToken.sol
# > Compiling @openzeppelin/contracts/GSN/Context.sol
# > Compiling @openzeppelin/contracts/math/SafeMath.sol
# > Compiling @openzeppelin/contracts/token/ERC20/ERC20.sol
# > Compiling @openzeppelin/contracts/token/ERC20/IERC20.sol
# > Artifacts written to /Users/saintway/JHub/demo-ethereum-dapp/Learn-Drizzle/unbox-drizzle/app/src/contracts
# > Compiled successfully using:
#    - solc: 0.5.16+commit.9c3226ce.Emscripten.clang

# %%
truffle migrate --reset --network develop
# Out:
# Compiling your contracts...
# ...
# > Everything is up to date, there is nothing to compile.
#
#
#
# Starting migrations...
# ...
# > Network name:    'develop'
# > Network id:      5777
# > Block gas limit: 6721975 (0x6691b7)
#
#
# 1_initial_migration.js
# ...
#
#    Deploying 'Migrations'
#    ----------------------
#    > transaction hash:    0x0804951d03dad48d9dfa1d6d6abceae1cede9e5fc7cfecbeca3faa336444c3bc
#    ⠋ Blocks: 0            Seconds: 0   > Blocks: 0            Seconds: 0
#    > contract address:    0xD0d13fd0F75c3aaa775266d84C37520c23e65c95
#    > block number:        216
#    > block timestamp:     1605538367
#    > account:             0xe642f1a103867EE5100b197A4cF083185aD78438
#    > balance:             95.00989926
#    > gas used:            164175 (0x2814f)
#    > gas price:           20 gwei
#    > value sent:          0 ETH
#    > total cost:          0.0032835 ETH
#
#
#    ⠋ Saving migration to chain.   > Saving migration to chain.
#    > Saving artifacts
# ...

# %%
cd app && npm run start
# Out:
# > app@0.1.0 start
# > react-scripts start
#
# Starting the development server...
#
# Browserslist: caniuse-lite is outdated. Please run next command `yarn upgrade`
# Compiled successfully!
#
# You can now view app in the browser.
#
#   Local:            http://localhost:3000/
#   On Your Network:  http://172.20.10.8:3000/
#
# Note that the development build is not optimized.
# To create a production build, use yarn build.
