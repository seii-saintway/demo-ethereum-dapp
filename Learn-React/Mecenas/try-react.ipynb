# %% [markdown]
# https://kartojal.github.io/mecenas/
#
# ```
# git clone https://github.com/kartojal/mecenas.git
# ```

# %%
ncu
# Out:
# Checking /Users/saintway/JHub/demo-ethereum-dapp/Learn-React/Mecenas/package.json
# [--------------------] 0/38 0%[=-------------------] 1/38 2%[==------------------] 4/38 10%[===-----------------] 5/38 13%[====----------------] 8/38 21%[=====---------------] 10/38 26%[======--------------] 12/38 31%[=======-------------] 13/38 34%[=======-------------] 14/38 36%[========------------] 16/38 42%[=========-----------] 18/38 47%[===========---------] 20/38 52%[===========---------] 21/38 55%[============--------] 22/38 57%[============--------] 23/38 60%[=============-------] 25/38 65%[==============------] 27/38 71%[===============-----] 29/38 76%[================----] 30/38 78%[================----] 31/38 81%[=================---] 33/38 86%[==================--] 34/38 89%[==================--] 35/38 92%[===================-] 36/38 94%[===================-] 37/38 97%[====================] 38/38 100%
#
#  @babel/preset-react                 ^7.12.1  →  ^7.12.5
#  @wojtekmaj/enzyme-adapter-react-17   ^0.2.0  →   ^0.3.1
#  babel-jest                          ^26.6.1  →  ^26.6.3
#  babel-loader                         ^8.1.0  →   ^8.2.1
#  css-loader                           ^5.0.0  →   ^5.0.1
#  imagemin-gifsicle                     6.0.1  →    7.0.0
#  jest                                ^26.6.1  →  ^26.6.3
#  node-sass                           ^4.14.1  →   ^5.0.0
#  sass-loader                         ^10.0.4  →  ^10.1.0
#  webpack                             ^4.43.0  →   ^5.4.0
#  webpack-cli                         ^3.3.12  →   ^4.2.0
#  webpack-dev-middleware               ^3.7.2  →   ^4.0.2
#  webpack-merge                        ^4.2.2  →   ^5.4.0
#
# Run ncu -u to upgrade package.json

# %%
ncu -u

# %% [markdown]
# [use an m3.large instance type for npm](https://npme.npmjs.com/docs/up-and-running/requirements.html#note-on-aws)

# %%
yarn install

# %%
yarn start
# Out:
# yarn run v1.22.10
# $ yarn run start-dev
# $ webpack-dev-server --config=configs/webpack/dev
# ℹ ｢wds｣: Project is running at http://localhost:8080/
# ℹ ｢wds｣: webpack output is served from /
# ℹ ｢wds｣: Content not from webpack is served from /Users/saintway/JHub/demo-ethereum-dapp/Learn-React/Mecenas
# ✖ ｢wdm｣: Hash: 59c40cf584e6ab9c79f7
# Version: webpack 4.44.2
# Time: 5508ms
# Built at: 11/16/2020 2:44:22 AM
#                                    Asset      Size  Chunks                                Chunk Names
#                              favicon.ico  31.3 KiB          [emitted]
# img/024d4cc4f72329ee94610b3c9db71623.png    23 KiB          [emitted] [immutable]
# img/2949ede2f41ff76f1aa64ecd370b853c.png  1.31 KiB          [emitted] [immutable]
# img/403a814f63665b9019e007435f9bc915.svg  45.3 KiB          [emitted] [immutable]
# img/6206c708729ad6638c02a1ac3ed76e03.svg  94.8 KiB          [emitted] [immutable]
# img/acdeab272bc275c87037d13a12e35fe5.svg  2.35 KiB          [emitted] [immutable]
# img/bbaa289ced7295ee49b02c07dd7993a8.svg  45.3 KiB          [emitted] [immutable]
# img/e051adc71952abd32a67d5b9c23cc3bc.jpg   168 KiB          [emitted] [immutable]
# img/e24940e6b6db72f531d790d54eb7f0a6.png  9.15 KiB          [emitted] [immutable]
#                               index.html  2.49 KiB          [emitted]
#                                  main.js  10.1 MiB    main  [emitted]              [big]  main
# Entrypoint main [big] = main.js
# [0] multi ../node_modules/webpack-dev-server/client?http://localhost:8080 ../node_modules/webpack/hot/dev-server.js react-hot-loader/patch webpack-dev-server/client?http://localhost:8080 webpack/hot/only-dev-server ./index.js 88 bytes {main} [built]
# [../node_modules/@hot-loader/react-dom/index.js] 1.33 KiB {main} [built]
# [../node_modules/react-hot-loader/dist/react-hot-loader.development.js] 98.2 KiB {main} [built]
# [../node_modules/react-hot-loader/patch.js] 229 bytes {main} [built]
# [../node_modules/react-router-dom/esm/react-router-dom.js] 10.1 KiB {main} [built]
# [../node_modules/strip-ansi/index.js] 161 bytes {main} [built]
# [../node_modules/webpack-dev-server/client/index.js?http://localhost:8080] ../node_modules/webpack-dev-server/client?http://localhost:8080 4.29 KiB {main} [built]
# [../node_modules/webpack-dev-server/client/overlay.js] 3.51 KiB {main} [built]
# [../node_modules/webpack-dev-server/client/socket.js] 1.53 KiB {main} [built]
# [../node_modules/webpack-dev-server/client/utils/createSocketUrl.js] 2.91 KiB {main} [built]
# [../node_modules/webpack-dev-server/client/utils/log.js] 964 bytes {main} [built]
# [../node_modules/webpack-dev-server/client/utils/reloadApp.js] 1.59 KiB {main} [built]
# [../node_modules/webpack/hot/dev-server.js] 1.59 KiB {main} [built]
# [../node_modules/webpack/hot/only-dev-server.js] 2.52 KiB {main} [built]
# [./index.js] 2.58 KiB {main} [built]
#     + 428 hidden modules
#
# ERROR in ./components/Toolbar.js
# Module not found: Error: Can't resolve 'classnames' in '/Users/saintway/JHub/demo-ethereum-dapp/Learn-React/Mecenas/src/components'
#  @ ./components/Toolbar.js 37:0-36 125:19-29 144:19-29 154:19-29
#  @ ./App.js
#  @ ./index.js
#  @ multi react-hot-loader/patch webpack-dev-server/client?http://localhost:8080 webpack/hot/only-dev-server ./index.js
#
# ERROR in ./components/be_mecenas/BeMecenasView.js
# Module not found: Error: Can't resolve 'classnames' in '/Users/saintway/JHub/demo-ethereum-dapp/Learn-React/Mecenas/src/components/be_mecenas'
#  @ ./components/be_mecenas/BeMecenasView.js 44:0-36
#  @ ./index.js
#  @ multi react-hot-loader/patch webpack-dev-server/client?http://localhost:8080 webpack/hot/only-dev-server ./index.js
#
# ERROR in ./components/be_mecenas/Top.js
# Module not found: Error: Can't resolve 'classnames' in '/Users/saintway/JHub/demo-ethereum-dapp/Learn-React/Mecenas/src/components/be_mecenas'
#  @ ./components/be_mecenas/Top.js 40:0-36 121:19-29 130:19-29
#  @ ./components/be_mecenas/BeMecenasView.js
#  @ ./index.js
#  @ multi react-hot-loader/patch webpack-dev-server/client?http://localhost:8080 webpack/hot/only-dev-server ./index.js
#
# ERROR in ./components/content_creator/Top.js
# Module not found: Error: Can't resolve 'classnames' in '/Users/saintway/JHub/demo-ethereum-dapp/Learn-React/Mecenas/src/components/content_creator'
#  @ ./components/content_creator/Top.js 44:0-36 193:19-29 202:19-29 237:19-29 290:19-29
#  @ ./components/content_creator/ContentCreatorView.js
#  @ ./index.js
#  @ multi react-hot-loader/patch webpack-dev-server/client?http://localhost:8080 webpack/hot/only-dev-server ./index.js
#
# ERROR in ./components/content_creator/MessageInbox.js
# Module not found: Error: Can't resolve 'classnames' in '/Users/saintway/JHub/demo-ethereum-dapp/Learn-React/Mecenas/src/components/content_creator'
#  @ ./components/content_creator/MessageInbox.js 38:0-36
#  @ ./components/content_creator/ContentCreatorView.js
#  @ ./index.js
#  @ multi react-hot-loader/patch webpack-dev-server/client?http://localhost:8080 webpack/hot/only-dev-server ./index.js
#
# ERROR in ./components/home/LatestCreators.js
# Module not found: Error: Can't resolve 'classnames' in '/Users/saintway/JHub/demo-ethereum-dapp/Learn-React/Mecenas/src/components/home'
#  @ ./components/home/LatestCreators.js 46:0-36 178:21-31
#  @ ./components/home/Home.js
#  @ ./index.js
#  @ multi react-hot-loader/patch webpack-dev-server/client?http://localhost:8080 webpack/hot/only-dev-server ./index.js
#
# ERROR in ./components/registry/Registry.js
# Module not found: Error: Can't resolve 'classnames' in '/Users/saintway/JHub/demo-ethereum-dapp/Learn-React/Mecenas/src/components/registry'
#  @ ./components/registry/Registry.js 45:0-36 322:19-29 377:19-29
#  @ ./index.js
#  @ multi react-hot-loader/patch webpack-dev-server/client?http://localhost:8080 webpack/hot/only-dev-server ./index.js
#
# ERROR in ./index.js
# Module not found: Error: Can't resolve 'drizzle' in '/Users/saintway/JHub/demo-ethereum-dapp/Learn-React/Mecenas/src'
#  @ ./index.js 15:0-49 17:19-32 18:18-25
#  @ multi react-hot-loader/patch webpack-dev-server/client?http://localhost:8080 webpack/hot/only-dev-server ./index.js
#
# ERROR in ./index.js
# Module not found: Error: Can't resolve 'drizzle-react' in '/Users/saintway/JHub/demo-ethereum-dapp/Learn-React/Mecenas/src'
#  @ ./index.js 16:0-47 28:50-64
#  @ multi react-hot-loader/patch webpack-dev-server/client?http://localhost:8080 webpack/hot/only-dev-server ./index.js
#
# ERROR in ./util/withDrizzleContext.js
# Module not found: Error: Can't resolve 'drizzle-react' in '/Users/saintway/JHub/demo-ethereum-dapp/Learn-React/Mecenas/src/util'
#  @ ./util/withDrizzleContext.js 35:0-47 95:48-62
#  @ ./components/content_creator/ContentCreatorView.js
#  @ ./index.js
#  @ multi react-hot-loader/patch webpack-dev-server/client?http://localhost:8080 webpack/hot/only-dev-server ./index.js
#
# ERROR in ./util/withDrizzleContextSimple.js
# Module not found: Error: Can't resolve 'drizzle-react' in '/Users/saintway/JHub/demo-ethereum-dapp/Learn-React/Mecenas/src/util'
#  @ ./util/withDrizzleContextSimple.js 35:0-47 53:48-62
#  @ ./components/content_creator/Tiers.js
#  @ ./components/content_creator/ContentCreatorView.js
#  @ ./index.js
#  @ multi react-hot-loader/patch webpack-dev-server/client?http://localhost:8080 webpack/hot/only-dev-server ./index.js
#
# ERROR in ./index.js
# Module not found: Error: Can't resolve 'drizzle-react-components' in '/Users/saintway/JHub/demo-ethereum-dapp/Learn-React/Mecenas/src'
#  @ ./index.js 26:0-60
#  @ multi react-hot-loader/patch webpack-dev-server/client?http://localhost:8080 webpack/hot/only-dev-server ./index.js
#
# ERROR in ./components/content_creator/Tiers.js
# Module not found: Error: Can't resolve 'drizzle-react-components' in '/Users/saintway/JHub/demo-ethereum-dapp/Learn-React/Mecenas/src/components/content_creator'
#  @ ./components/content_creator/Tiers.js 43:0-83
#  @ ./components/content_creator/ContentCreatorView.js
#  @ ./index.js
#  @ multi react-hot-loader/patch webpack-dev-server/client?http://localhost:8080 webpack/hot/only-dev-server ./index.js
#
# ERROR in ./components/content_creator/Tier.js
# Module not found: Error: Can't resolve 'drizzle-react-components' in '/Users/saintway/JHub/demo-ethereum-dapp/Learn-React/Mecenas/src/components/content_creator'
#  @ ./components/content_creator/Tier.js 37:0-83
#  @ ./components/content_creator/Tiers.js
#  @ ./components/content_creator/ContentCreatorView.js
#  @ ./index.js
#  @ multi react-hot-loader/patch webpack-dev-server/client?http://localhost:8080 webpack/hot/only-dev-server ./index.js
#
# ERROR in ./components/registry/IpfsUpload.js
# Module not found: Error: Can't resolve 'ipfs-api/lib/index.js' in '/Users/saintway/JHub/demo-ethereum-dapp/Learn-React/Mecenas/src/components/registry'
#  @ ./components/registry/IpfsUpload.js 37:0-44 150:24-31
#  @ ./components/registry/Registry.js
#  @ ./index.js
#  @ multi react-hot-loader/patch webpack-dev-server/client?http://localhost:8080 webpack/hot/only-dev-server ./index.js
#
# ERROR in ./components/be_mecenas/BeMecenasView.js
# Module not found: Error: Can't resolve 'react-placeholder' in '/Users/saintway/JHub/demo-ethereum-dapp/Learn-React/Mecenas/src/components/be_mecenas'
#  @ ./components/be_mecenas/BeMecenasView.js 52:0-49
#  @ ./index.js
#  @ multi react-hot-loader/patch webpack-dev-server/client?http://localhost:8080 webpack/hot/only-dev-server ./index.js
#
# ERROR in ./components/be_mecenas/Top.js
# Module not found: Error: Can't resolve 'react-placeholder' in '/Users/saintway/JHub/demo-ethereum-dapp/Learn-React/Mecenas/src/components/be_mecenas'
#  @ ./components/be_mecenas/Top.js 50:0-49 119:42-58 137:42-58
#  @ ./components/be_mecenas/BeMecenasView.js
#  @ ./index.js
#  @ multi react-hot-loader/patch webpack-dev-server/client?http://localhost:8080 webpack/hot/only-dev-server ./index.js
#
# ERROR in ./components/be_mecenas/stepper/0_SelectTier.js
# Module not found: Error: Can't resolve 'react-placeholder' in '/Users/saintway/JHub/demo-ethereum-dapp/Learn-React/Mecenas/src/components/be_mecenas/stepper'
#  @ ./components/be_mecenas/stepper/0_SelectTier.js 40:0-49
#  @ ./components/be_mecenas/BeMecenasView.js
#  @ ./index.js
#  @ multi react-hot-loader/patch webpack-dev-server/client?http://localhost:8080 webpack/hot/only-dev-server ./index.js
#
# ERROR in ./components/be_mecenas/stepper/PureTier.js
# Module not found: Error: Can't resolve 'react-placeholder' in '/Users/saintway/JHub/demo-ethereum-dapp/Learn-React/Mecenas/src/components/be_mecenas/stepper'
#  @ ./components/be_mecenas/stepper/PureTier.js 34:0-49
#  @ ./components/be_mecenas/stepper/0_SelectTier.js
#  @ ./components/be_mecenas/BeMecenasView.js
#  @ ./index.js
#  @ multi react-hot-loader/patch webpack-dev-server/client?http://localhost:8080 webpack/hot/only-dev-server ./index.js
#
# ERROR in ./components/content_creator/Tiers.js
# Module not found: Error: Can't resolve 'react-placeholder' in '/Users/saintway/JHub/demo-ethereum-dapp/Learn-React/Mecenas/src/components/content_creator'
#  @ ./components/content_creator/Tiers.js 47:0-49
#  @ ./components/content_creator/ContentCreatorView.js
#  @ ./index.js
#  @ multi react-hot-loader/patch webpack-dev-server/client?http://localhost:8080 webpack/hot/only-dev-server ./index.js
#
# ERROR in ./components/content_creator/MessageInbox.js
# Module not found: Error: Can't resolve 'react-placeholder' in '/Users/saintway/JHub/demo-ethereum-dapp/Learn-React/Mecenas/src/components/content_creator'
#  @ ./components/content_creator/MessageInbox.js 48:0-49
#  @ ./components/content_creator/ContentCreatorView.js
#  @ ./index.js
#  @ multi react-hot-loader/patch webpack-dev-server/client?http://localhost:8080 webpack/hot/only-dev-server ./index.js
#
# ERROR in ./components/content_creator/Description.js
# Module not found: Error: Can't resolve 'react-placeholder' in '/Users/saintway/JHub/demo-ethereum-dapp/Learn-React/Mecenas/src/components/content_creator'
#  @ ./components/content_creator/Description.js 43:0-49 82:42-58
#  @ ./components/content_creator/ContentCreatorView.js
#  @ ./index.js
#  @ multi react-hot-loader/patch webpack-dev-server/client?http://localhost:8080 webpack/hot/only-dev-server ./index.js
#
# ERROR in ./components/content_creator/LeftSidebar.js
# Module not found: Error: Can't resolve 'react-placeholder' in '/Users/saintway/JHub/demo-ethereum-dapp/Learn-React/Mecenas/src/components/content_creator'
#  @ ./components/content_creator/LeftSidebar.js 43:0-49 84:42-58
#  @ ./components/content_creator/ContentCreatorView.js
#  @ ./index.js
#  @ multi react-hot-loader/patch webpack-dev-server/client?http://localhost:8080 webpack/hot/only-dev-server ./index.js
#
# ERROR in ./components/content_creator/Top.js
# Module not found: Error: Can't resolve 'react-placeholder' in '/Users/saintway/JHub/demo-ethereum-dapp/Learn-React/Mecenas/src/components/content_creator'
#  @ ./components/content_creator/Top.js 55:0-49 191:42-58 209:42-58 253:42-58 269:42-58
#  @ ./components/content_creator/ContentCreatorView.js
#  @ ./index.js
#  @ multi react-hot-loader/patch webpack-dev-server/client?http://localhost:8080 webpack/hot/only-dev-server ./index.js
#
# ERROR in ./components/content_creator/Tier.js
# Module not found: Error: Can't resolve 'react-placeholder' in '/Users/saintway/JHub/demo-ethereum-dapp/Learn-React/Mecenas/src/components/content_creator'
#  @ ./components/content_creator/Tier.js 41:0-49
#  @ ./components/content_creator/Tiers.js
#  @ ./components/content_creator/ContentCreatorView.js
#  @ ./index.js
#  @ multi react-hot-loader/patch webpack-dev-server/client?http://localhost:8080 webpack/hot/only-dev-server ./index.js
#
# ERROR in ./App.js
# Module not found: Error: Can't resolve 'react-placeholder/lib/reactPlaceholder.css' in '/Users/saintway/JHub/demo-ethereum-dapp/Learn-React/Mecenas/src'
#  @ ./App.js 43:0-52
#  @ ./index.js
#  @ multi react-hot-loader/patch webpack-dev-server/client?http://localhost:8080 webpack/hot/only-dev-server ./index.js
#
# ERROR in ./components/content_creator/LeftSidebar.js
# Module not found: Error: Can't resolve 'react-share' in '/Users/saintway/JHub/demo-ethereum-dapp/Learn-React/Mecenas/src/components/content_creator'
#  @ ./components/content_creator/LeftSidebar.js 47:0-231 98:42-61 102:42-54 105:44-63 108:42-54 111:44-62 115:42-53 118:44-63 121:42-54 124:44-63 128:42-54 131:44-60 135:42-51
#  @ ./components/content_creator/ContentCreatorView.js
#  @ ./index.js
#  @ multi react-hot-loader/patch webpack-dev-server/client?http://localhost:8080 webpack/hot/only-dev-server ./index.js
#
# ERROR in ./components/content_creator/MessageInbox.js
# Module not found: Error: Can't resolve 'react-slick' in '/Users/saintway/JHub/demo-ethereum-dapp/Learn-React/Mecenas/src/components/content_creator'
#  @ ./components/content_creator/MessageInbox.js 51:0-33 198:75-81
#  @ ./components/content_creator/ContentCreatorView.js
#  @ ./index.js
#  @ multi react-hot-loader/patch webpack-dev-server/client?http://localhost:8080 webpack/hot/only-dev-server ./index.js
#
# ERROR in ./App.js
# Module not found: Error: Can't resolve 'slick-carousel/slick/slick-theme.css' in '/Users/saintway/JHub/demo-ethereum-dapp/Learn-React/Mecenas/src'
#  @ ./App.js 45:0-46
#  @ ./index.js
#  @ multi react-hot-loader/patch webpack-dev-server/client?http://localhost:8080 webpack/hot/only-dev-server ./index.js
#
# ERROR in ./App.js
# Module not found: Error: Can't resolve 'slick-carousel/slick/slick.css' in '/Users/saintway/JHub/demo-ethereum-dapp/Learn-React/Mecenas/src'
#  @ ./App.js 44:0-40
#  @ ./index.js
#  @ multi react-hot-loader/patch webpack-dev-server/client?http://localhost:8080 webpack/hot/only-dev-server ./index.js
#
# ERROR in ./App.js
# Module not found: Error: Can't resolve 'typeface-roboto' in '/Users/saintway/JHub/demo-ethereum-dapp/Learn-React/Mecenas/src'
#  @ ./App.js 37:0-25
#  @ ./index.js
#  @ multi react-hot-loader/patch webpack-dev-server/client?http://localhost:8080 webpack/hot/only-dev-server ./index.js
#
# ERROR in ./components/home/Home.js
# Module not found: Error: Can't resolve 'video-react' in '/Users/saintway/JHub/demo-ethereum-dapp/Learn-React/Mecenas/src/components/home'
#  @ ./components/home/Home.js 36:0-86 150:42-48 156:43-56 158:43-51 160:43-53
#  @ ./index.js
#  @ multi react-hot-loader/patch webpack-dev-server/client?http://localhost:8080 webpack/hot/only-dev-server ./index.js
#
# ERROR in ./components/home/Home.js
# Module not found: Error: Can't resolve 'video-react/dist/video-react.css' in '/Users/saintway/JHub/demo-ethereum-dapp/Learn-React/Mecenas/src/components/home'
#  @ ./components/home/Home.js 45:0-42
#  @ ./index.js
#  @ multi react-hot-loader/patch webpack-dev-server/client?http://localhost:8080 webpack/hot/only-dev-server ./index.js
#
# ERROR in ./mecenas-store/ContentCreator.js
# Module not found: Error: Can't resolve 'web3' in '/Users/saintway/JHub/demo-ethereum-dapp/Learn-React/Mecenas/src/mecenas-store'
#  @ ./mecenas-store/ContentCreator.js 10:0-24 29:64-68 30:30-34 31:27-31
#  @ ./components/content_creator/ContentCreatorView.js
#  @ ./index.js
#  @ multi react-hot-loader/patch webpack-dev-server/client?http://localhost:8080 webpack/hot/only-dev-server ./index.js
#
# ERROR in ./fonts/Open-Sans-regular/Open-Sans-regular.eot 1:1
# Module parse failed: Identifier directly after number (1:1)
# You may need an appropriate loader to handle this file type, currently no loaders are configured to process this file. See https://webpack.js.org/concepts#loaders
# (Source code omitted for this binary file)
#  @ ./css/open-sans.css (../node_modules/css-loader/dist/cjs.js??ref--5-1!./css/open-sans.css) 5:0-93 11:73-102 12:73-102
#  @ ./css/open-sans.css
#  @ ./App.js
#  @ ./index.js
#  @ multi react-hot-loader/patch webpack-dev-server/client?http://localhost:8080 webpack/hot/only-dev-server ./index.js
#
# ERROR in ./media/ContentCreator.mp4 1:0
# Module parse failed: Unexpected character '' (1:0)
# You may need an appropriate loader to handle this file type, currently no loaders are configured to process this file. See https://webpack.js.org/concepts#loaders
# (Source code omitted for this binary file)
#  @ ./components/home/Home.js 44:0-69 155:13-36
#  @ ./index.js
#  @ multi react-hot-loader/patch webpack-dev-server/client?http://localhost:8080 webpack/hot/only-dev-server ./index.js
#
# ERROR in ./fonts/Open-Sans-regular/Open-Sans-regular.ttf 1:0
# Module parse failed: Unexpected character '' (1:0)
# You may need an appropriate loader to handle this file type, currently no loaders are configured to process this file. See https://webpack.js.org/concepts#loaders
# (Source code omitted for this binary file)
#  @ ./css/open-sans.css (../node_modules/css-loader/dist/cjs.js??ref--5-1!./css/open-sans.css) 8:0-93 15:73-102
#  @ ./css/open-sans.css
#  @ ./App.js
#  @ ./index.js
#  @ multi react-hot-loader/patch webpack-dev-server/client?http://localhost:8080 webpack/hot/only-dev-server ./index.js
#
# ERROR in ./fonts/Oswald-regular/Oswald-regular.ttf 1:0
# Module parse failed: Unexpected character '' (1:0)
# You may need an appropriate loader to handle this file type, currently no loaders are configured to process this file. See https://webpack.js.org/concepts#loaders
# (Source code omitted for this binary file)
#  @ ./css/oswald.css (../node_modules/css-loader/dist/cjs.js??ref--5-1!./css/oswald.css) 13:0-87 26:74-103
#  @ ./css/oswald.css
#  @ ./App.js
#  @ ./index.js
#  @ multi react-hot-loader/patch webpack-dev-server/client?http://localhost:8080 webpack/hot/only-dev-server ./index.js
#
# ERROR in ./fonts/Oswald-300/Oswald-300.ttf 1:0
# Module parse failed: Unexpected character '' (1:0)
# You may need an appropriate loader to handle this file type, currently no loaders are configured to process this file. See https://webpack.js.org/concepts#loaders
# (Source code omitted for this binary file)
#  @ ./css/oswald.css (../node_modules/css-loader/dist/cjs.js??ref--5-1!./css/oswald.css) 8:0-79 20:73-102
#  @ ./css/oswald.css
#  @ ./App.js
#  @ ./index.js
#  @ multi react-hot-loader/patch webpack-dev-server/client?http://localhost:8080 webpack/hot/only-dev-server ./index.js
#
# ERROR in ./fonts/Oswald-300/Oswald-300.eot 1:2
# Module parse failed: Unexpected character '' (1:2)
# You may need an appropriate loader to handle this file type, currently no loaders are configured to process this file. See https://webpack.js.org/concepts#loaders
# (Source code omitted for this binary file)
#  @ ./css/oswald.css (../node_modules/css-loader/dist/cjs.js??ref--5-1!./css/oswald.css) 5:0-79 16:73-102 17:73-102
#  @ ./css/oswald.css
#  @ ./App.js
#  @ ./index.js
#  @ multi react-hot-loader/patch webpack-dev-server/client?http://localhost:8080 webpack/hot/only-dev-server ./index.js
#
# ERROR in ./fonts/Oswald-regular/Oswald-regular.woff 1:4
# Module parse failed: Unexpected character '' (1:4)
# You may need an appropriate loader to handle this file type, currently no loaders are configured to process this file. See https://webpack.js.org/concepts#loaders
# (Source code omitted for this binary file)
#  @ ./css/oswald.css (../node_modules/css-loader/dist/cjs.js??ref--5-1!./css/oswald.css) 12:0-88 25:73-102
#  @ ./css/oswald.css
#  @ ./App.js
#  @ ./index.js
#  @ multi react-hot-loader/patch webpack-dev-server/client?http://localhost:8080 webpack/hot/only-dev-server ./index.js
#
# ERROR in ./fonts/Oswald-regular/Oswald-regular.woff2 1:4
# Module parse failed: Unexpected character '' (1:4)
# You may need an appropriate loader to handle this file type, currently no loaders are configured to process this file. See https://webpack.js.org/concepts#loaders
# (Source code omitted for this binary file)
#  @ ./css/oswald.css (../node_modules/css-loader/dist/cjs.js??ref--5-1!./css/oswald.css) 11:0-89 24:73-102
#  @ ./css/oswald.css
#  @ ./App.js
#  @ ./index.js
#  @ multi react-hot-loader/patch webpack-dev-server/client?http://localhost:8080 webpack/hot/only-dev-server ./index.js
#
# ERROR in ./fonts/Oswald-300/Oswald-300.woff 1:4
# Module parse failed: Unexpected character '' (1:4)
# You may need an appropriate loader to handle this file type, currently no loaders are configured to process this file. See https://webpack.js.org/concepts#loaders
# (Source code omitted for this binary file)
#  @ ./css/oswald.css (../node_modules/css-loader/dist/cjs.js??ref--5-1!./css/oswald.css) 7:0-80 19:73-102
#  @ ./css/oswald.css
#  @ ./App.js
#  @ ./index.js
#  @ multi react-hot-loader/patch webpack-dev-server/client?http://localhost:8080 webpack/hot/only-dev-server ./index.js
#
# ERROR in ./fonts/Oswald-300/Oswald-300.woff2 1:4
# Module parse failed: Unexpected character '' (1:4)
# You may need an appropriate loader to handle this file type, currently no loaders are configured to process this file. See https://webpack.js.org/concepts#loaders
# (Source code omitted for this binary file)
#  @ ./css/oswald.css (../node_modules/css-loader/dist/cjs.js??ref--5-1!./css/oswald.css) 6:0-81 18:73-102
#  @ ./css/oswald.css
#  @ ./App.js
#  @ ./index.js
#  @ multi react-hot-loader/patch webpack-dev-server/client?http://localhost:8080 webpack/hot/only-dev-server ./index.js
#
# ERROR in ./fonts/Open-Sans-regular/Open-Sans-regular.woff 1:4
# Module parse failed: Unexpected character '' (1:4)
# You may need an appropriate loader to handle this file type, currently no loaders are configured to process this file. See https://webpack.js.org/concepts#loaders
# (Source code omitted for this binary file)
#  @ ./css/open-sans.css (../node_modules/css-loader/dist/cjs.js??ref--5-1!./css/open-sans.css) 7:0-94 14:73-102
#  @ ./css/open-sans.css
#  @ ./App.js
#  @ ./index.js
#  @ multi react-hot-loader/patch webpack-dev-server/client?http://localhost:8080 webpack/hot/only-dev-server ./index.js
#
# ERROR in ./fonts/Open-Sans-regular/Open-Sans-regular.woff2 1:4
# Module parse failed: Unexpected character '' (1:4)
# You may need an appropriate loader to handle this file type, currently no loaders are configured to process this file. See https://webpack.js.org/concepts#loaders
# (Source code omitted for this binary file)
#  @ ./css/open-sans.css (../node_modules/css-loader/dist/cjs.js??ref--5-1!./css/open-sans.css) 6:0-95 13:73-102
#  @ ./css/open-sans.css
#  @ ./App.js
#  @ ./index.js
#  @ multi react-hot-loader/patch webpack-dev-server/client?http://localhost:8080 webpack/hot/only-dev-server ./index.js
#
# ERROR in ./fonts/Oswald-regular/Oswald-regular.eot 1:0
# Module parse failed: Unexpected character '' (1:0)
# You may need an appropriate loader to handle this file type, currently no loaders are configured to process this file. See https://webpack.js.org/concepts#loaders
# (Source code omitted for this binary file)
#  @ ./css/oswald.css (../node_modules/css-loader/dist/cjs.js??ref--5-1!./css/oswald.css) 10:0-87 22:73-102 23:73-102
#  @ ./css/oswald.css
#  @ ./App.js
#  @ ./index.js
#  @ multi react-hot-loader/patch webpack-dev-server/client?http://localhost:8080 webpack/hot/only-dev-server ./index.js
# Child HtmlWebpackCompiler:
#      1 asset
#     Entrypoint HtmlWebpackPlugin_0 = __child-HtmlWebpackPlugin_0
#     [../node_modules/html-webpack-plugin/lib/loader.js!./index.html.ejs] 2.76 KiB {HtmlWebpackPlugin_0} [built]
# ℹ ｢wdm｣: Failed to compile.
